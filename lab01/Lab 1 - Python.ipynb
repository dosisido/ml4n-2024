# %% [markdown]
# # Lab #1

# %% [markdown]
# The purpose of this laboratory is to get you acquainted with Python.
# More specifically, you will learn how to:
# - read different types of datasets (CSV and JSON).
# - extract some useful information (mean and standard deviation) from the datasets while only using basic python.
# - create a simple rule-based classifier that is already capable to perform some classification.

# %% [markdown]
# ## Preliminaries
# ### Python availability
# Make sure that Python 3 is installed on your device with the commands `python --version`. The version should be in the form `3.x.x.`

# %%
! python --version
! wget "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data" -O iris.csv
! wget "https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/mnist_test.csv" -O mnist.csv
# Out:
# Python 3.12.6
# --2024-11-19 12:19:43--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: 'iris.csv'
#
#      0K ....                                                   12,8M=0s
#
# 2024-11-19 12:19:43 (12,8 MB/s) - 'iris.csv' saved [4551]
#
# --2024-11-19 12:19:44--  https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/mnist_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18289443 (17M) [text/plain]
# Saving to: 'mnist.csv'
#
#      0K .......... .......... .......... .......... ..........  0% 4,96M 4s
#     50K .......... .......... .......... .......... ..........  0% 18,4M 2s
#    100K .......... .......... .......... .......... ..........  0% 11,6M 2s
#    150K .......... .......... .......... .......... ..........  1% 11,6M 2s
#    200K .......... .......... .......... .......... ..........  1% 9,37M 2s
#    250K .......... .......... .......... .......... ..........  1% 12,8M 2s
#    300K .......... .......... .......... .......... ..........  1% 11,5M 2s
#    350K .......... .......... .......... .......... ..........  2% 5,74M 2s
#    400K .......... .......... .......... .......... ..........  2% 58,8M 2s
#    450K .......... .......... .......... .......... ..........  2% 11,7M 2s
#    500K .......... .......... .......... .......... ..........  3% 12,1M 2s
#    550K .......... .......... .......... .......... ..........  3% 8,08M 2s
#    600K .......... .......... .......... .......... ..........  3% 21,5M 2s
#    650K .......... .......... .......... .......... ..........  3% 11,8M 2s
#    700K .......... .......... .......... .......... ..........  4% 11,6M 2s
#    750K .......... .......... .......... .......... ..........  4% 8,60M 2s
#    800K .......... .......... .......... .......... ..........  4% 17,7M 2s
#    850K .......... .......... .......... .......... ..........  5% 9,01M 2s
#    900K .......... .......... .......... .......... ..........  5% 11,9M 2s
#    950K .......... .......... .......... .......... ..........  5% 9,72M 2s
#   1000K .......... .......... .......... .......... ..........  5% 13,3M 2s
#   1050K .......... .......... .......... .......... ..........  6% 12,0M 2s
#   1100K .......... .......... .......... .......... ..........  6% 11,6M 2s
#   1150K .......... .......... .......... .......... ..........  6% 9,57M 2s
#   1200K .......... .......... .......... .......... ..........  6% 15,0M 1s
#   1250K .......... .......... .......... .......... ..........  7% 11,9M 1s
#   1300K .......... .......... .......... .......... ..........  7% 11,6M 1s
#   1350K .......... .......... .......... .......... ..........  7% 8,85M 1s
#   1400K .......... .......... .......... .......... ..........  8% 11,0M 1s
#   1450K .......... .......... .......... .......... ..........  8% 12,5M 1s
#   1500K .......... .......... .......... .......... ..........  8% 11,9M 1s
#   1550K .......... .......... .......... .......... ..........  8% 10,1M 1s
#   1600K .......... .......... .......... .......... ..........  9% 14,4M 1s
#   1650K .......... .......... .......... .......... ..........  9% 9,26M 1s
#  16200K .......... .......... .......... .......... .......... 90% 9,02M 0s
#  16250K .......... .......... .......... .......... .......... 91% 11,6M 0s
#  16300K .......... .......... .......... .......... .......... 91% 8,87M 0s
#  16350K .......... .......... .......... .......... .......... 91% 17,0M 0s
#  16400K .......... .......... .......... .......... .......... 92% 13,6M 0s
#  16450K .......... .......... .......... .......... .......... 92% 8,67M 0s
#  16500K .......... .......... .......... .......... .......... 92% 9,73M 0s
#  16550K .......... .......... .......... .......... .......... 92% 14,8M 0s
#  16600K .......... .......... .......... .......... .......... 93% 11,9M 0s
#  16650K .......... .......... .......... .......... .......... 93% 10,9M 0s
#  16700K .......... .......... .......... .......... .......... 93% 10,0M 0s
#  16750K .......... .......... .......... .......... .......... 94% 15,8M 0s
#  16800K .......... .......... .......... .......... .......... 94% 11,6M 0s
#  16850K .......... .......... .......... .......... .......... 94% 8,84M 0s
#  16900K .......... .......... .......... .......... .......... 94% 10,1M 0s
#  16950K .......... .......... .......... .......... .......... 95% 14,0M 0s
#  17000K .......... .......... .......... .......... .......... 95% 12,6M 0s
#  17050K .......... .......... .......... .......... .......... 95% 12,3M 0s
#  17100K .......... .......... .......... .......... .......... 96% 11,4M 0s
#  17150K .......... .......... .......... .......... .......... 96% 8,95M 0s
#  17200K .......... .......... .......... .......... .......... 96% 11,6M 0s
#  17250K .......... .......... .......... .......... .......... 96% 11,9M 0s
#  17300K .......... .......... .......... .......... .......... 97% 11,7M 0s
#  17350K .......... .......... .......... .......... .......... 97% 6,89M 0s
#  17400K .......... .......... .......... .......... .......... 97% 40,1M 0s
#  17450K .......... .......... .......... .......... .......... 97% 11,7M 0s
#  17500K .......... .......... .......... .......... .......... 98% 11,0M 0s
#  17550K .......... .......... .......... .......... .......... 98% 10,1M 0s
#  17600K .......... .......... .......... .......... .......... 98% 11,9M 0s
#  17650K .......... .......... .......... .......... .......... 99% 8,24M 0s
#  17700K .......... .......... .......... .......... .......... 99% 18,0M 0s
#  17750K .......... .......... .......... .......... .......... 99% 12,5M 0s
#  17800K .......... .......... .......... .......... .......... 99% 9,77M 0s
#  17850K ..........                                            100%  206G=1,6s
#
# 2024-11-19 12:19:45 (11,2 MB/s) - 'mnist.csv' saved [18289443/18289443]

# %%
IRIS = "iris.csv"
MNIST = "mnist.csv"

# %%
from typing import List
def mean_fn(data: List[List[float]]) -> List[float]:
    return [sum(col)/len(col) for col in zip(*data)]

def std_fn(data: List[List[float]], means: List[float]) -> List[float]:
    assert len(data[0]) == len(means)
    return [pow(sum((x - m)**2 for x in col) / len(col), 1/2) for col, m in zip(zip(*data), means)]

# %% [markdown]
# ### Dataset Download
# For this lab, three different datasets will be used. Here, you will learnmore about them and how to retrieve
# them.

# %% [markdown]
# #### Iris
# Iris is a particularly famous *toy dataset* (i.e. a dataset with a small number of rows and columns, mostly
# used for initial small-scale tests and proofs of concept).
# This specific dataset contains information about the **Iris**, a genus that includes 260-300 species of plants.
# The Iris dataset contains measurements for 150 Iris flowers, each belonging to one of three species (50 flowers each):
#
# Iris Virginica             |  Iris Versicolor          |   Iris Setosa  |
# :-------------------------:|:-------------------------:|:---------------|
# :<img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Iris_virginica_2.jpg/1200px-Iris_virginica_2.jpg" alt="Iris Virginica" width="200" /> | <img src="https://www.waternursery.it/document/img_prodotti/616/1646318149.jpeg" alt="Iris Versicolor" width="200" /> |<img src="https://d2j6dbq0eux0bg.cloudfront.net/images/28296135/2323483832.jpg" alt="Iris Setosa" width="200" />|
#
# Each of the 150 flowers contained in the Iris dataset is represented by 5 values:
# - sepal length, in cm
# - sepal width, in cm
# - petal length, in cm
# - petal width, in cm
# - Iris species, one of: Iris-setosa, Iris-versicolor, Iris-virginica (the label)
#
# Each row of the dataset represents a distinct flower (as such, the dataset will have 150 rows). Each
# row then contains 5 values (4 measurements and a species label).
# The dataset is described in more detail on the [UCI Machine Learning Repository website](https://archive.ics.uci.edu/dataset/53/iris). The dataset
# can either be downloaded directly from there (iris.data file), or from a terminal, using the `wget` tool. The
# following command downloads the dataset from the original URL and stores it in a file named iris.csv.
#
# `wget "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data" -O iris.csv`
#
# The dataset is available as a Comma-Separated Values (CSV) file. These files are typically used to
# represent tabular data.
# - Each row is represented on one of the lines.
# - Each of the rows contains a fixed number of columns.
# - Each of the columns (in each row) is separated by a comma (,).
#
# To read CSV files, Python offers a module called `csv` (here the offical [doc](https://docs.python.org/3/library/csv.html)). This module allows using `csv.reader()`, which
# reads a file row by row. For each row, it returns a list of columns that can be processed as needed.
#
#
# Let's download the dataset and print the first three rows.

# %%
import csv

print("Reading first lines of IRIS dataset")
with open(IRIS) as f:
    for i, cols in enumerate(csv.reader(f)):
        print(cols)
        if i >= 4:
            break
# Out:
# Reading first lines of IRIS dataset
# ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa']

# %% [markdown]
# Note by default, csv.reader converts all fields read into strings (str).
# If you want to treat them as number, remember to cast them correctly!

# %% [markdown]
# #### MNIST
# The MNIST dataset is another particularly famous dataset. It contains several thousands of hand-written
# digits (0 to 9).
# - Each hand-written digit is contained in an image represented as $28 x 28$ 8-bit grayscale image.
# - This means that each digit has $784$ ($28^2$) pixels
# - Each pixel has a value that ranges from 0 (black) to 255 (white).
#
# <img src="https://machinelearningmastery.com/wp-content/uploads/2019/02/Plot-of-a-Subset-of-Images-from-the-MNIST-Dataset.png" alt="MNIST images" width="500" />
#
# The dataset can be downloaded from the following link:
#
# [https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/mnist_test.csv](https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/mnist_test.csv)
#
# In this case, MNIST is represented as a CSV file. Similarly to the Iris dataset, each row of the MNIST
# datasets represents the pixels of the image representing a digit. For the sake of simplicity, this dataset contains only a small fraction (10; 000
# digits out of 70; 000) of the real MNIST dataset.
#
# For each digit, 785 values are available:
# - the first one is the numerical value depicted in the image (e.g. for Figure 2 it would be 5).
# - the following 784 columns represent the grayscale image in row-major order (for more information about row- and column-major order of matrices, see [Wikipedia](https://en.wikipedia.org/wiki/Row-_and_column-major_order)).
#
# The MNIST dataset in CSV format can be read with the same approach used for Iris, keeping in mind
# that, in this case, the digit label (i.e. the first column) is an integer from 0 to 9, while the following 784
# values are integers between 0 and 255.

# %% [markdown]
# ## Exercises
# Note that exercises marked with a (*) are optional, you should focus on completing the other ones first.
# ### Iris analysis
# 1. Load the previously downloaded Iris dataset as a list of lists (each of the 150 lists should have 5 elements). You can make use of the csv module presented

# %%
import csv

def try_callback(n:str, cb):
    try:
        return cb(n)
    except:
        return n


iris_data = []
with open(IRIS) as f:
    for cols in csv.reader(f):
        if len(cols) != 5: continue
        iris_data.append(list([try_callback(x, float) for x in cols]))
        
[print(x) for i,x in enumerate(iris_data) if i <5]
# Out:
# [5.1, 3.5, 1.4, 0.2, 'Iris-setosa']
# [4.9, 3.0, 1.4, 0.2, 'Iris-setosa']
# [4.7, 3.2, 1.3, 0.2, 'Iris-setosa']
# [4.6, 3.1, 1.5, 0.2, 'Iris-setosa']
# [5.0, 3.6, 1.4, 0.2, 'Iris-setosa']
# [None, None, None, None, None]

# %% [markdown]
# 2. Compute and print the mean and the standard deviation for each of the 4 measurement columns (i.e. sepal length and width, petal length and width). Remember that, for a given list of n values $x = (x_1, x_2, ..., x_n)$, the mean $\mu$ and the standard deviation $\sigma$ are defined respectively as:
# $$\mu = {1 \over n} \sum_i^n x_i $$
#
# $$ \sigma = \sqrt{ {1 \over n} \sum_i^n (x_i - \mu)^2} $$

# %%
mean = mean_fn([x[:-1] for x in iris_data])
std = std_fn([x[:-1] for x in iris_data], mean)

print(mean)
print(std)
# Out:
# [5.843333333333334, 3.0540000000000003, 3.758666666666666, 1.1986666666666668]
# [0.8253012917851409, 0.43214658007054346, 1.758529183405521, 0.7606126185881716]

# %% [markdown]
# 3. Compute and print the mean and the standard deviation for each of the 4 measurement columns, separately for each of the three Iris species (versicolor, virginica and setosa).

# %%
species = set(x[-1] for x in iris_data)
splitted_data = {spec: [x[:-1] for x in iris_data if x[-1] == spec] for spec in species}

mean_species = {spec: mean_fn(data) for spec, data in splitted_data.items()}
std_species = {spec: std_fn(data, mean_species[spec]) for spec, data in splitted_data.items()}

for spec in species:
	print(f"{spec} mean: {mean_species[spec]}")
	print(f"{spec} std: {std_species[spec]}")
	print()

species_data = {
	spec: {
		"data": data,
		"mean": mean_species[spec],
		"std": std_species[spec]
	} for spec, data in splitted_data.items()
}
# Out:
# Iris-virginica mean: [6.587999999999999, 2.9739999999999998, 5.5520000000000005, 2.026]
# Iris-virginica std: [0.6294886813914926, 0.3192553836664309, 0.546347874526844, 0.2718896835115301]
#
# Iris-versicolor mean: [5.936, 2.77, 4.26, 1.3259999999999998]
# Iris-versicolor std: [0.5109833656783751, 0.31064449134018135, 0.4651881339845203, 0.19576516544063705]
#
# Iris-setosa mean: [5.006, 3.418, 1.464, 0.24400000000000002]
# Iris-setosa std: [0.3489469873777391, 0.37719490982779713, 0.17176728442867112, 0.10613199329137281]

# %% [markdown]
# 4. Based on the results of exercises 2 and 3, which of the 4 measurements would you considering as being the most characterizing one for the three species? (In other words, which measurement would you consider “best”, if you were to guess the Iris species based only on those four values?)

# %% [markdown]
# The forth, because have the most distinct mean and low std

# %% [markdown]
# 5. Based on the considerations of Exercise 3, assign the flowers with the following measurements to what you consider would be the most likely species.
# ````
# 5.2, 3.1, 4.0, 1.2
# 4.9, 2.5, 5.6, 2.0
# 5.4, 3.2, 1.9, 0.4
# ````

# %% [markdown]
# ````
# 5.2, 3.1, 4.0, 1.2 -> Verisicolor
# 4.9, 2.5, 5.6, 2.0 -> Virgninica
# 5.4, 3.2, 1.9, 0.4 -> Setosa
# ````

# %% [markdown]
# 6. (*) Create a Rule-based classifier similar to the one seen in class. This classifier, again, will receive some rule and will classify each sample into one of the three species.

# %%
def classifier(data: List[float]) -> str:
    distances = {
        spec: abs(data[-1] - specs["mean"][-1]) for spec, specs in species_data.items()
    }
    return min(distances, key=distances.get)

[print(classifier(x)) for x in (
    (5.2, 3.1, 4.0, 1.2),
    (4.9, 2.5, 5.6, 2.0),
    (5.4, 3.2, 1.9, 0.4)
)]
# Out:
# Iris-versicolor
# Iris-virginica
# Iris-setosa
# [None, None, None]

# %% [markdown]
# 7. (*) Compute prediction for all the elements in the dataset and store them in a list. Then, compute the accuracy of the classifier that you create. Remember that the accuracy metric is:
#
# $$ {\text{number of correct predictions (TP + TN)} \over \text{total number of predictions (TP+TN+FP+FN)}} $$
#
# Where one can check whether the prediction is correct by looking at the label of the sample ($5^{th}$ column)

# %%
with_prediction = [
    x + [classifier(x[:-1])] for x in iris_data
]

correct = sum(1 for x in with_prediction if x[-1] == x[-2])
print("Accuracy", correct/len(with_prediction))
# Out:
# Accuracy 0.96

# %% [markdown]
# ### MNIST Analysis
#
# 1. Load the previously downloaded MNIST dataset. You can make use of the csv module already presented.

# %%
import csv

mnist_data = []
with open(MNIST) as f:
    for cols in csv.reader(f):
        if len(cols) != 785: continue
        mnist_data.append(list([try_callback(x, int) for x in cols]))

# %% [markdown]
# 2. Create a function that, given a position $1 < k < 10,000$, prints the $k^{th}$ sample of the dataset (i.e. the $k^{th}$ row of the csv file) as a grid of $28x28$ characters. More specifically, you should map each range of pixel values to the following characters:
#     - [0; 64) &rarr; " "
#     - [64; 128) &rarr; "."
#     - [128; 192) &rarr; "*"
#     - [192; 256) &rarr; "#"
# So, for example, you should map the sequence `0, 72, 192, 138, 250` to the string `.#*#`.
# *Note*: Remember to start a new line every time you read 28 characters
#
# Example of output:
# ```
#          .#      **
#         .##..*#####
#        #########*.
#       #####***.
#      ##*
#     *##
#     ##
#    .##
#     ###*
#     .#####.
#         *###*
#            *###*
#               ###
#               .##
#               ###
#             .###
#       .    *###.
#      .#  .*###*
#      .######.
#       *##*.
# ```

# %%
from random import random
def pretty_print(data: List[int]):
    mapping = lambda x: " " if (x//64)%4 == 0 else '.' if (x//64)%4 == 1 else '*' if (x//64)%4 == 2 else '#'

    for i in range(1, len(data), 28):
        print(''.join([mapping(x) for x in data[i: i+28]]))

pretty_print(mnist_data[int(random() * len(mnist_data))])
# Out:
#
#
#
#
#
#               *#####.
#             *########
#           .#####***##*
#           ###*.    ##*
#          *##*      ##.
#          ###       ##*
#          ##*      *##
#          ###      ##
#          .##*    .#.
#           ###    ..
#            ###
#            .###. .****.
#            .#########*.
#           #######.
#          ####*###.
#          ##*   *#.
#          ##.   *#*
#          *##. .##*
#           #######.
#            *####.

# %% [markdown]
# 3. Compute the Euclidean distance between each pair of the 784-dimensional vectors of the digits at
# the following positions: $26^{th}$, $30^{th}$, $32^{nd}$, $35^{th}$.
#
# *Note*: Remember that Python arrays are indexed from 0, so the $k^{th}$ value will be at position $k-1$

# %%
def euc_distance(a, b):
    return pow(sum([(x - y) ** 2 for x, y in zip(a, b)]), 1 / 2)
# 
indexes = [25, 29, 31, 34]

for i in indexes:
    for j in indexes:
        if i == j: continue
        print(i, j, euc_distance(mnist_data[i][1:], mnist_data[j][1:]))
    print()
# Out:
# 25 29 3539.223219860539
# 25 31 3556.4199695761467
# 25 34 3223.2069434027967
#
# 29 25 3539.223219860539
# 29 31 1171.8293391104355
# 29 34 2531.0033583541526
#
# 31 25 3556.4199695761467
# 31 29 1171.8293391104355
# 31 34 2515.5599774205343
#
# 34 25 3223.2069434027967
# 34 29 2531.0033583541526
# 34 31 2515.5599774205343

# %% [markdown]
# 4. Based on the distances computed in the previous step and knowing that the digits listed in Exercise 3 are (not necessarily in this order) $0, 1, 1, 7$ can you assign the correct label to each of the digits of Exercise 3?

# %% [markdown]
# 25: 0
# 29: 1
# 31: 1
# 34:

# %% [markdown]
# 5. There are 1,135 images representing 1’s and 980 images representing 0’s in the dataset. For all 0’s and 1’s separately, count the number of times each of the 784 pixels is black (use 128 as the threshold value). You can do this by building a list `Z` and a list `O`, each containing 784 elements, containing respectively the counts for the 0’s and the 1’s. `Z[i]` and `O[i]` contain the number of times the $i^{th}$ pixel was black for either class. For each value i, compute `abs(Z[i] - O[i])`. The $i$ with the highest value represents the pixel that best separates the digits “0” and “1” (i.e. the pixel that is most often black for one class and white for the other). Where is this pixel located within the grid? Why is it?

# %%
only_zero = [x[1:] for x in mnist_data if x[0] == 0]
only_one = [x[1:] for x in mnist_data if x[0] == 1]

print(len(only_zero), len(only_one))

Z = [ sum(col) for col in zip(*[[1 if el > 128 else 0 for el in row] for row in only_zero])]
O = [ sum(col) for col in zip(*[[1 if el > 128 else 0 for el in row] for row in only_one])]

a = [(i, abs(z-o)) for i, (z, o) in enumerate(zip(Z, O))]

m = (-1, 0)
for i, dist in a:
    if dist > m[1]: m = (i, dist)
    print(f"{i}) {dist= }, {Z[i]=}, {O[i]=}")
print(f"Highest dist {m[1]} at pixel {m[0]} located in position {m[0] //28}x{m[0]%28}")
# Out:
# 980 1135
# 0) dist= 0, Z[i]=0, O[i]=0
# 1) dist= 0, Z[i]=0, O[i]=0
# 2) dist= 0, Z[i]=0, O[i]=0
# 3) dist= 0, Z[i]=0, O[i]=0
# 4) dist= 0, Z[i]=0, O[i]=0
# 5) dist= 0, Z[i]=0, O[i]=0
# 6) dist= 0, Z[i]=0, O[i]=0
# 7) dist= 0, Z[i]=0, O[i]=0
# 8) dist= 0, Z[i]=0, O[i]=0
# 9) dist= 0, Z[i]=0, O[i]=0
# 10) dist= 0, Z[i]=0, O[i]=0
# 11) dist= 0, Z[i]=0, O[i]=0
# 12) dist= 0, Z[i]=0, O[i]=0
# 13) dist= 0, Z[i]=0, O[i]=0
# 14) dist= 0, Z[i]=0, O[i]=0
# 15) dist= 0, Z[i]=0, O[i]=0
# 16) dist= 0, Z[i]=0, O[i]=0
# 17) dist= 0, Z[i]=0, O[i]=0
# 18) dist= 0, Z[i]=0, O[i]=0
# 19) dist= 0, Z[i]=0, O[i]=0
# 20) dist= 0, Z[i]=0, O[i]=0
# 21) dist= 0, Z[i]=0, O[i]=0
# 22) dist= 0, Z[i]=0, O[i]=0
# 23) dist= 0, Z[i]=0, O[i]=0
# 24) dist= 0, Z[i]=0, O[i]=0
# 25) dist= 0, Z[i]=0, O[i]=0
# 26) dist= 0, Z[i]=0, O[i]=0
# 27) dist= 0, Z[i]=0, O[i]=0
# 28) dist= 0, Z[i]=0, O[i]=0
# 29) dist= 0, Z[i]=0, O[i]=0
# 30) dist= 0, Z[i]=0, O[i]=0
# 31) dist= 0, Z[i]=0, O[i]=0
# 32) dist= 0, Z[i]=0, O[i]=0
# 33) dist= 0, Z[i]=0, O[i]=0
# 34) dist= 0, Z[i]=0, O[i]=0
# 35) dist= 0, Z[i]=0, O[i]=0
# 36) dist= 0, Z[i]=0, O[i]=0
# 37) dist= 0, Z[i]=0, O[i]=0
# 38) dist= 0, Z[i]=0, O[i]=0
# 39) dist= 0, Z[i]=0, O[i]=0
# 40) dist= 0, Z[i]=0, O[i]=0
# 41) dist= 0, Z[i]=0, O[i]=0
# 42) dist= 0, Z[i]=0, O[i]=0
# 43) dist= 0, Z[i]=0, O[i]=0
# 44) dist= 0, Z[i]=0, O[i]=0
# 45) dist= 0, Z[i]=0, O[i]=0
# 46) dist= 0, Z[i]=0, O[i]=0
# 47) dist= 0, Z[i]=0, O[i]=0
# 48) dist= 0, Z[i]=0, O[i]=0
# 49) dist= 0, Z[i]=0, O[i]=0
# 50) dist= 0, Z[i]=0, O[i]=0
# 51) dist= 0, Z[i]=0, O[i]=0
# 52) dist= 0, Z[i]=0, O[i]=0
# 53) dist= 0, Z[i]=0, O[i]=0
# 54) dist= 0, Z[i]=0, O[i]=0
# 55) dist= 0, Z[i]=0, O[i]=0
# 56) dist= 0, Z[i]=0, O[i]=0
# 57) dist= 0, Z[i]=0, O[i]=0
# 58) dist= 0, Z[i]=0, O[i]=0
# 59) dist= 0, Z[i]=0, O[i]=0
# 60) dist= 0, Z[i]=0, O[i]=0
# 61) dist= 0, Z[i]=0, O[i]=0
# 62) dist= 0, Z[i]=0, O[i]=0
# 63) dist= 0, Z[i]=0, O[i]=0
# 64) dist= 0, Z[i]=0, O[i]=0
# 65) dist= 0, Z[i]=0, O[i]=0
# 66) dist= 0, Z[i]=0, O[i]=0
# 67) dist= 1, Z[i]=0, O[i]=1
# 68) dist= 3, Z[i]=0, O[i]=3
# 69) dist= 2, Z[i]=0, O[i]=2
# 70) dist= 1, Z[i]=0, O[i]=1
# 71) dist= 0, Z[i]=0, O[i]=0
# 72) dist= 0, Z[i]=0, O[i]=0
# 73) dist= 0, Z[i]=0, O[i]=0
# 74) dist= 0, Z[i]=0, O[i]=0
# 75) dist= 1, Z[i]=1, O[i]=0
# 76) dist= 1, Z[i]=1, O[i]=0
# 77) dist= 0, Z[i]=0, O[i]=0
# 78) dist= 0, Z[i]=0, O[i]=0
# 79) dist= 0, Z[i]=0, O[i]=0
# 80) dist= 0, Z[i]=0, O[i]=0
# 81) dist= 0, Z[i]=0, O[i]=0
# 82) dist= 0, Z[i]=0, O[i]=0
# 83) dist= 0, Z[i]=0, O[i]=0
# 84) dist= 0, Z[i]=0, O[i]=0
# 85) dist= 0, Z[i]=0, O[i]=0
# 86) dist= 0, Z[i]=0, O[i]=0
# 87) dist= 0, Z[i]=0, O[i]=0
# 88) dist= 0, Z[i]=0, O[i]=0
# 89) dist= 0, Z[i]=0, O[i]=0
# 90) dist= 0, Z[i]=0, O[i]=0
# 91) dist= 0, Z[i]=0, O[i]=0
# 92) dist= 0, Z[i]=0, O[i]=0
# 93) dist= 0, Z[i]=0, O[i]=0
# 94) dist= 2, Z[i]=2, O[i]=0
# 95) dist= 1, Z[i]=2, O[i]=1
# 96) dist= 0, Z[i]=3, O[i]=3
# 97) dist= 5, Z[i]=9, O[i]=4
# 98) dist= 9, Z[i]=14, O[i]=5
# 99) dist= 17, Z[i]=20, O[i]=3
# 100) dist= 25, Z[i]=27, O[i]=2
# 101) dist= 14, Z[i]=20, O[i]=6
# 102) dist= 9, Z[i]=13, O[i]=4
# 103) dist= 5, Z[i]=9, O[i]=4
# 104) dist= 5, Z[i]=6, O[i]=1
# 105) dist= 1, Z[i]=1, O[i]=0
# 106) dist= 3, Z[i]=3, O[i]=0
# 107) dist= 2, Z[i]=2, O[i]=0
# 108) dist= 0, Z[i]=0, O[i]=0
# 109) dist= 0, Z[i]=0, O[i]=0
# 110) dist= 0, Z[i]=0, O[i]=0
# 111) dist= 0, Z[i]=0, O[i]=0
# 112) dist= 0, Z[i]=0, O[i]=0
# 113) dist= 0, Z[i]=0, O[i]=0
# 114) dist= 0, Z[i]=0, O[i]=0
# 115) dist= 0, Z[i]=0, O[i]=0
# 116) dist= 0, Z[i]=0, O[i]=0
# 117) dist= 0, Z[i]=0, O[i]=0
# 118) dist= 1, Z[i]=1, O[i]=0
# 119) dist= 1, Z[i]=1, O[i]=0
# 120) dist= 1, Z[i]=1, O[i]=0
# 121) dist= 7, Z[i]=10, O[i]=3
# 122) dist= 20, Z[i]=28, O[i]=8
# 123) dist= 34, Z[i]=60, O[i]=26
# 124) dist= 50, Z[i]=108, O[i]=58
# 125) dist= 59, Z[i]=170, O[i]=111
# 126) dist= 19, Z[i]=213, O[i]=194
# 127) dist= 70, Z[i]=275, O[i]=205
# 128) dist= 82, Z[i]=266, O[i]=184
# 129) dist= 47, Z[i]=221, O[i]=174
# 130) dist= 24, Z[i]=166, O[i]=142
# 131) dist= 14, Z[i]=115, O[i]=101
# 132) dist= 12, Z[i]=58, O[i]=70
# 133) dist= 0, Z[i]=35, O[i]=35
# 134) dist= 4, Z[i]=13, O[i]=17
# 135) dist= 3, Z[i]=6, O[i]=3
# 136) dist= 0, Z[i]=2, O[i]=2
# 137) dist= 0, Z[i]=0, O[i]=0
# 138) dist= 0, Z[i]=0, O[i]=0
# 139) dist= 0, Z[i]=0, O[i]=0
# 140) dist= 0, Z[i]=0, O[i]=0
# 141) dist= 0, Z[i]=0, O[i]=0
# 142) dist= 0, Z[i]=0, O[i]=0
# 143) dist= 0, Z[i]=0, O[i]=0
# 144) dist= 0, Z[i]=0, O[i]=0
# 145) dist= 0, Z[i]=0, O[i]=0
# 146) dist= 2, Z[i]=2, O[i]=0
# 147) dist= 3, Z[i]=4, O[i]=1
# 148) dist= 9, Z[i]=11, O[i]=2
# 149) dist= 30, Z[i]=35, O[i]=5
# 150) dist= 72, Z[i]=85, O[i]=13
# 151) dist= 136, Z[i]=181, O[i]=45
# 152) dist= 185, Z[i]=299, O[i]=114
# 153) dist= 181, Z[i]=419, O[i]=238
# 154) dist= 161, Z[i]=526, O[i]=365
# 155) dist= 140, Z[i]=570, O[i]=430
# 156) dist= 181, Z[i]=572, O[i]=391
# 157) dist= 174, Z[i]=535, O[i]=361
# 158) dist= 145, Z[i]=428, O[i]=283
# 159) dist= 81, Z[i]=296, O[i]=215
# 160) dist= 61, Z[i]=192, O[i]=131
# 161) dist= 32, Z[i]=98, O[i]=66
# 162) dist= 18, Z[i]=49, O[i]=31
# 163) dist= 2, Z[i]=12, O[i]=10
# 164) dist= 5, Z[i]=5, O[i]=0
# 165) dist= 2, Z[i]=2, O[i]=0
# 166) dist= 0, Z[i]=0, O[i]=0
# 167) dist= 0, Z[i]=0, O[i]=0
# 168) dist= 0, Z[i]=0, O[i]=0
# 169) dist= 0, Z[i]=0, O[i]=0
# 170) dist= 0, Z[i]=0, O[i]=0
# 171) dist= 0, Z[i]=0, O[i]=0
# 172) dist= 0, Z[i]=0, O[i]=0
# 173) dist= 3, Z[i]=3, O[i]=0
# 174) dist= 4, Z[i]=4, O[i]=0
# 175) dist= 15, Z[i]=16, O[i]=1
# 176) dist= 40, Z[i]=42, O[i]=2
# 177) dist= 98, Z[i]=102, O[i]=4
# 178) dist= 192, Z[i]=206, O[i]=14
# 179) dist= 295, Z[i]=347, O[i]=52
# 180) dist= 353, Z[i]=492, O[i]=139
# 181) dist= 325, Z[i]=612, O[i]=287
# 182) dist= 225, Z[i]=686, O[i]=461
# 183) dist= 185, Z[i]=729, O[i]=544
# 184) dist= 212, Z[i]=715, O[i]=503
# 185) dist= 260, Z[i]=689, O[i]=429
# 186) dist= 298, Z[i]=633, O[i]=335
# 187) dist= 258, Z[i]=496, O[i]=238
# 188) dist= 203, Z[i]=349, O[i]=146
# 189) dist= 135, Z[i]=205, O[i]=70
# 190) dist= 74, Z[i]=102, O[i]=28
# 191) dist= 18, Z[i]=24, O[i]=6
# 192) dist= 5, Z[i]=6, O[i]=1
# 193) dist= 2, Z[i]=2, O[i]=0
# 194) dist= 0, Z[i]=0, O[i]=0
# 195) dist= 0, Z[i]=0, O[i]=0
# 196) dist= 0, Z[i]=0, O[i]=0
# 197) dist= 0, Z[i]=0, O[i]=0
# 198) dist= 0, Z[i]=0, O[i]=0
# 199) dist= 0, Z[i]=0, O[i]=0
# 200) dist= 1, Z[i]=1, O[i]=0
# 201) dist= 3, Z[i]=3, O[i]=0
# 202) dist= 11, Z[i]=13, O[i]=2
# 203) dist= 32, Z[i]=34, O[i]=2
# 204) dist= 92, Z[i]=94, O[i]=2
# 205) dist= 188, Z[i]=193, O[i]=5
# 206) dist= 327, Z[i]=341, O[i]=14
# 207) dist= 449, Z[i]=497, O[i]=48
# 208) dist= 466, Z[i]=598, O[i]=132
# 209) dist= 353, Z[i]=671, O[i]=318
# 210) dist= 199, Z[i]=718, O[i]=519
# 211) dist= 113, Z[i]=730, O[i]=617
# 212) dist= 145, Z[i]=711, O[i]=566
# 213) dist= 222, Z[i]=693, O[i]=471
# 214) dist= 346, Z[i]=690, O[i]=344
# 215) dist= 395, Z[i]=619, O[i]=224
# 216) dist= 362, Z[i]=481, O[i]=119
# 217) dist= 305, Z[i]=352, O[i]=47
# 218) dist= 170, Z[i]=185, O[i]=15
# 219) dist= 54, Z[i]=57, O[i]=3
# 220) dist= 8, Z[i]=8, O[i]=0
# 221) dist= 0, Z[i]=0, O[i]=0
# 222) dist= 0, Z[i]=0, O[i]=0
# 223) dist= 0, Z[i]=0, O[i]=0
# 224) dist= 0, Z[i]=0, O[i]=0
# 225) dist= 0, Z[i]=0, O[i]=0
# 226) dist= 0, Z[i]=0, O[i]=0
# 227) dist= 0, Z[i]=0, O[i]=0
# 228) dist= 4, Z[i]=4, O[i]=0
# 229) dist= 5, Z[i]=6, O[i]=1
# 230) dist= 19, Z[i]=21, O[i]=2
# 231) dist= 75, Z[i]=78, O[i]=3
# 232) dist= 169, Z[i]=172, O[i]=3
# 233) dist= 309, Z[i]=314, O[i]=5
# 234) dist= 467, Z[i]=478, O[i]=11
# 235) dist= 560, Z[i]=599, O[i]=39
# 236) dist= 541, Z[i]=667, O[i]=126
# 237) dist= 355, Z[i]=684, O[i]=329
# 238) dist= 34, Z[i]=630, O[i]=596
# 239) dist= 113, Z[i]=586, O[i]=699
# 240) dist= 47, Z[i]=559, O[i]=606
# 241) dist= 94, Z[i]=575, O[i]=481
# 242) dist= 315, Z[i]=630, O[i]=315
# 243) dist= 486, Z[i]=663, O[i]=177
# 244) dist= 513, Z[i]=594, O[i]=81
# 245) dist= 411, Z[i]=442, O[i]=31
# 246) dist= 287, Z[i]=292, O[i]=5
# 247) dist= 120, Z[i]=120, O[i]=0
# 248) dist= 18, Z[i]=18, O[i]=0
# 249) dist= 1, Z[i]=1, O[i]=0
# 250) dist= 0, Z[i]=0, O[i]=0
# 251) dist= 0, Z[i]=0, O[i]=0
# 252) dist= 0, Z[i]=0, O[i]=0
# 253) dist= 0, Z[i]=0, O[i]=0
# 254) dist= 0, Z[i]=0, O[i]=0
# 255) dist= 0, Z[i]=0, O[i]=0
# 256) dist= 3, Z[i]=4, O[i]=1
# 257) dist= 8, Z[i]=9, O[i]=1
# 258) dist= 46, Z[i]=48, O[i]=2
# 259) dist= 140, Z[i]=142, O[i]=2
# 260) dist= 251, Z[i]=254, O[i]=3
# 261) dist= 436, Z[i]=440, O[i]=4
# 262) dist= 570, Z[i]=579, O[i]=9
# 263) dist= 633, Z[i]=667, O[i]=34
# 264) dist= 540, Z[i]=657, O[i]=117
# 265) dist= 218, Z[i]=572, O[i]=354
# 266) dist= 196, Z[i]=477, O[i]=673
# 267) dist= 414, Z[i]=386, O[i]=800
# 268) dist= 313, Z[i]=343, O[i]=656
# 269) dist= 64, Z[i]=389, O[i]=453
# 270) dist= 242, Z[i]=499, O[i]=257
# 271) dist= 495, Z[i]=615, O[i]=120
# 272) dist= 590, Z[i]=629, O[i]=39
# 273) dist= 531, Z[i]=545, O[i]=14
# 274) dist= 376, Z[i]=378, O[i]=2
# 275) dist= 184, Z[i]=185, O[i]=1
# 276) dist= 35, Z[i]=36, O[i]=1
# 277) dist= 1, Z[i]=1, O[i]=0
# 278) dist= 0, Z[i]=0, O[i]=0
# 279) dist= 0, Z[i]=0, O[i]=0
# 280) dist= 0, Z[i]=0, O[i]=0
# 281) dist= 0, Z[i]=0, O[i]=0
# 282) dist= 0, Z[i]=0, O[i]=0
# 283) dist= 0, Z[i]=0, O[i]=0
# 284) dist= 4, Z[i]=4, O[i]=0
# 285) dist= 21, Z[i]=21, O[i]=0
# 286) dist= 89, Z[i]=90, O[i]=1
# 287) dist= 210, Z[i]=211, O[i]=1
# 288) dist= 366, Z[i]=367, O[i]=1
# 289) dist= 532, Z[i]=536, O[i]=4
# 290) dist= 661, Z[i]=666, O[i]=5
# 291) dist= 646, Z[i]=668, O[i]=22
# 292) dist= 432, Z[i]=545, O[i]=113
# 293) dist= 23, Z[i]=434, O[i]=411
# 294) dist= 467, Z[i]=313, O[i]=780
# 295) dist= 696, Z[i]=204, O[i]=900
# 296) dist= 497, Z[i]=168, O[i]=665
# 297) dist= 173, Z[i]=221, O[i]=394
# 298) dist= 167, Z[i]=353, O[i]=186
# 299) dist= 458, Z[i]=517, O[i]=59
# 300) dist= 603, Z[i]=624, O[i]=21
# 301) dist= 571, Z[i]=575, O[i]=4
# 302) dist= 466, Z[i]=468, O[i]=2
# 303) dist= 244, Z[i]=245, O[i]=1
# 304) dist= 66, Z[i]=67, O[i]=1
# 305) dist= 1, Z[i]=1, O[i]=0
# 306) dist= 0, Z[i]=0, O[i]=0
# 307) dist= 0, Z[i]=0, O[i]=0
# 308) dist= 0, Z[i]=0, O[i]=0
# 309) dist= 0, Z[i]=0, O[i]=0
# 310) dist= 0, Z[i]=0, O[i]=0
# 311) dist= 0, Z[i]=0, O[i]=0
# 312) dist= 4, Z[i]=4, O[i]=0
# 313) dist= 44, Z[i]=44, O[i]=0
# 314) dist= 150, Z[i]=150, O[i]=0
# 315) dist= 308, Z[i]=308, O[i]=0
# 316) dist= 490, Z[i]=491, O[i]=1
# 317) dist= 646, Z[i]=647, O[i]=1
# 318) dist= 670, Z[i]=674, O[i]=4
# 319) dist= 566, Z[i]=585, O[i]=19
# 320) dist= 330, Z[i]=440, O[i]=110
# 321) dist= 181, Z[i]=286, O[i]=467
# 322) dist= 748, Z[i]=166, O[i]=914
# 323) dist= 901, Z[i]=83, O[i]=984
# 324) dist= 552, Z[i]=72, O[i]=624
# 325) dist= 214, Z[i]=97, O[i]=311
# 326) dist= 125, Z[i]=231, O[i]=106
# 327) dist= 403, Z[i]=432, O[i]=29
# 328) dist= 583, Z[i]=591, O[i]=8
# 329) dist= 600, Z[i]=600, O[i]=0
# 330) dist= 511, Z[i]=511, O[i]=0
# 331) dist= 294, Z[i]=294, O[i]=0
# 332) dist= 101, Z[i]=101, O[i]=0
# 333) dist= 2, Z[i]=2, O[i]=0
# 334) dist= 0, Z[i]=0, O[i]=0
# 335) dist= 0, Z[i]=0, O[i]=0
# 336) dist= 0, Z[i]=0, O[i]=0
# 337) dist= 0, Z[i]=0, O[i]=0
# 338) dist= 0, Z[i]=0, O[i]=0
# 339) dist= 1, Z[i]=1, O[i]=0
# 340) dist= 7, Z[i]=7, O[i]=0
# 341) dist= 78, Z[i]=78, O[i]=0
# 342) dist= 234, Z[i]=234, O[i]=0
# 343) dist= 407, Z[i]=407, O[i]=0
# 344) dist= 590, Z[i]=591, O[i]=1
# 345) dist= 670, Z[i]=671, O[i]=1
# 346) dist= 617, Z[i]=621, O[i]=4
# 347) dist= 455, Z[i]=471, O[i]=16
# 348) dist= 184, Z[i]=294, O[i]=110
# 349) dist= 440, Z[i]=139, O[i]=579
# 350) dist= 995, Z[i]=50, O[i]=1045
# 351) dist= 979, Z[i]=29, O[i]=1008
# 352) dist= 534, Z[i]=26, O[i]=560
# 353) dist= 129, Z[i]=60, O[i]=189
# 354) dist= 139, Z[i]=181, O[i]=42
# 355) dist= 373, Z[i]=379, O[i]=6
# 356) dist= 579, Z[i]=581, O[i]=2
# 357) dist= 615, Z[i]=615, O[i]=0
# 358) dist= 528, Z[i]=528, O[i]=0
# 359) dist= 328, Z[i]=328, O[i]=0
# 360) dist= 121, Z[i]=121, O[i]=0
# 361) dist= 7, Z[i]=7, O[i]=0
# 362) dist= 0, Z[i]=0, O[i]=0
# 363) dist= 0, Z[i]=0, O[i]=0
# 364) dist= 0, Z[i]=0, O[i]=0
# 365) dist= 0, Z[i]=0, O[i]=0
# 366) dist= 0, Z[i]=0, O[i]=0
# 367) dist= 1, Z[i]=1, O[i]=0
# 368) dist= 17, Z[i]=17, O[i]=0
# 369) dist= 126, Z[i]=126, O[i]=0
# 370) dist= 328, Z[i]=328, O[i]=0
# 371) dist= 495, Z[i]=495, O[i]=0
# 372) dist= 655, Z[i]=655, O[i]=0
# 373) dist= 658, Z[i]=660, O[i]=2
# 374) dist= 546, Z[i]=549, O[i]=3
# 375) dist= 311, Z[i]=327, O[i]=16
# 376) dist= 20, Z[i]=170, O[i]=150
# 377) dist= 717, Z[i]=44, O[i]=761
# 378) dist= 1100, Z[i]=18, O[i]=1118
# 379) dist= 978, Z[i]=11, O[i]=989
# 380) dist= 424, Z[i]=6, O[i]=430
# 381) dist= 53, Z[i]=41, O[i]=94
# 382) dist= 153, Z[i]=164, O[i]=11
# 383) dist= 368, Z[i]=368, O[i]=0
# 384) dist= 556, Z[i]=559, O[i]=3
# 385) dist= 622, Z[i]=622, O[i]=0
# 386) dist= 530, Z[i]=530, O[i]=0
# 387) dist= 347, Z[i]=347, O[i]=0
# 388) dist= 120, Z[i]=120, O[i]=0
# 389) dist= 6, Z[i]=6, O[i]=0
# 390) dist= 0, Z[i]=0, O[i]=0
# 391) dist= 0, Z[i]=0, O[i]=0
# 392) dist= 0, Z[i]=0, O[i]=0
# 393) dist= 0, Z[i]=0, O[i]=0
# 394) dist= 0, Z[i]=0, O[i]=0
# 395) dist= 0, Z[i]=0, O[i]=0
# 396) dist= 30, Z[i]=30, O[i]=0
# 397) dist= 192, Z[i]=192, O[i]=0
# 398) dist= 397, Z[i]=397, O[i]=0
# 399) dist= 578, Z[i]=578, O[i]=0
# 400) dist= 671, Z[i]=671, O[i]=0
# 401) dist= 625, Z[i]=625, O[i]=0
# 402) dist= 425, Z[i]=429, O[i]=4
# 403) dist= 193, Z[i]=225, O[i]=32
# 404) dist= 181, Z[i]=72, O[i]=253
# 405) dist= 896, Z[i]=17, O[i]=913
# 406) dist= 1113, Z[i]=7, O[i]=1120
# 407) dist= 924, Z[i]=2, O[i]=926
# 408) dist= 280, Z[i]=4, O[i]=284
# 409) dist= 5, Z[i]=46, O[i]=41
# 410) dist= 176, Z[i]=178, O[i]=2
# 411) dist= 408, Z[i]=409, O[i]=1
# 412) dist= 578, Z[i]=580, O[i]=2
# 413) dist= 620, Z[i]=621, O[i]=1
# 414) dist= 509, Z[i]=510, O[i]=1
# 415) dist= 330, Z[i]=330, O[i]=0
# 416) dist= 112, Z[i]=112, O[i]=0
# 417) dist= 7, Z[i]=7, O[i]=0
# 418) dist= 0, Z[i]=0, O[i]=0
# 419) dist= 0, Z[i]=0, O[i]=0
# 420) dist= 0, Z[i]=0, O[i]=0
# 421) dist= 0, Z[i]=0, O[i]=0
# 422) dist= 0, Z[i]=0, O[i]=0
# 423) dist= 0, Z[i]=0, O[i]=0
# 424) dist= 39, Z[i]=39, O[i]=0
# 425) dist= 249, Z[i]=249, O[i]=0
# 426) dist= 451, Z[i]=451, O[i]=0
# 427) dist= 615, Z[i]=615, O[i]=0
# 428) dist= 678, Z[i]=678, O[i]=0
# 429) dist= 554, Z[i]=554, O[i]=0
# 430) dist= 321, Z[i]=334, O[i]=13
# 431) dist= 50, Z[i]=138, O[i]=88
# 432) dist= 385, Z[i]=34, O[i]=419
# 433) dist= 967, Z[i]=11, O[i]=978
# 434) dist= 1104, Z[i]=5, O[i]=1109
# 435) dist= 795, Z[i]=4, O[i]=799
# 436) dist= 160, Z[i]=17, O[i]=177
# 437) dist= 70, Z[i]=95, O[i]=25
# 438) dist= 245, Z[i]=247, O[i]=2
# 439) dist= 484, Z[i]=484, O[i]=0
# 440) dist= 628, Z[i]=629, O[i]=1
# 441) dist= 609, Z[i]=610, O[i]=1
# 442) dist= 463, Z[i]=464, O[i]=1
# 443) dist= 279, Z[i]=279, O[i]=0
# 444) dist= 101, Z[i]=101, O[i]=0
# 445) dist= 6, Z[i]=6, O[i]=0
# 446) dist= 0, Z[i]=0, O[i]=0
# 447) dist= 0, Z[i]=0, O[i]=0
# 448) dist= 0, Z[i]=0, O[i]=0
# 449) dist= 0, Z[i]=0, O[i]=0
# 450) dist= 0, Z[i]=0, O[i]=0
# 451) dist= 0, Z[i]=0, O[i]=0
# 452) dist= 57, Z[i]=57, O[i]=0
# 453) dist= 295, Z[i]=295, O[i]=0
# 454) dist= 488, Z[i]=488, O[i]=0
# 455) dist= 654, Z[i]=654, O[i]=0
# 456) dist= 665, Z[i]=665, O[i]=0
# 457) dist= 485, Z[i]=492, O[i]=7
# 458) dist= 220, Z[i]=262, O[i]=42
# 459) dist= 100, Z[i]=79, O[i]=179
# 460) dist= 532, Z[i]=16, O[i]=548
# 461) dist= 971, Z[i]=8, O[i]=979
# 462) dist= 1041, Z[i]=10, O[i]=1051
# 463) dist= 592, Z[i]=16, O[i]=608
# 464) dist= 79, Z[i]=63, O[i]=142
# 465) dist= 138, Z[i]=158, O[i]=20
# 466) dist= 373, Z[i]=375, O[i]=2
# 467) dist= 565, Z[i]=567, O[i]=2
# 468) dist= 655, Z[i]=658, O[i]=3
# 469) dist= 575, Z[i]=577, O[i]=2
# 470) dist= 412, Z[i]=413, O[i]=1
# 471) dist= 213, Z[i]=214, O[i]=1
# 472) dist= 58, Z[i]=59, O[i]=1
# 473) dist= 3, Z[i]=3, O[i]=0
# 474) dist= 0, Z[i]=0, O[i]=0
# 475) dist= 0, Z[i]=0, O[i]=0
# 476) dist= 0, Z[i]=0, O[i]=0
# 477) dist= 0, Z[i]=0, O[i]=0
# 478) dist= 0, Z[i]=0, O[i]=0
# 479) dist= 0, Z[i]=0, O[i]=0
# 480) dist= 84, Z[i]=84, O[i]=0
# 481) dist= 312, Z[i]=312, O[i]=0
# 482) dist= 517, Z[i]=517, O[i]=0
# 483) dist= 657, Z[i]=657, O[i]=0
# 484) dist= 642, Z[i]=648, O[i]=6
# 485) dist= 452, Z[i]=476, O[i]=24
# 486) dist= 129, Z[i]=226, O[i]=97
# 487) dist= 232, Z[i]=83, O[i]=315
# 488) dist= 603, Z[i]=23, O[i]=626
# 489) dist= 931, Z[i]=24, O[i]=955
# 490) dist= 875, Z[i]=35, O[i]=910
# 491) dist= 402, Z[i]=77, O[i]=479
# 492) dist= 35, Z[i]=165, O[i]=130
# 493) dist= 316, Z[i]=344, O[i]=28
# 494) dist= 529, Z[i]=537, O[i]=8
# 495) dist= 640, Z[i]=642, O[i]=2
# 496) dist= 641, Z[i]=645, O[i]=4
# 497) dist= 506, Z[i]=508, O[i]=2
# 498) dist= 319, Z[i]=320, O[i]=1
# 499) dist= 151, Z[i]=153, O[i]=2
# 500) dist= 33, Z[i]=34, O[i]=1
# 501) dist= 2, Z[i]=3, O[i]=1
# 502) dist= 0, Z[i]=0, O[i]=0
# 503) dist= 0, Z[i]=0, O[i]=0
# 504) dist= 0, Z[i]=0, O[i]=0
# 505) dist= 0, Z[i]=0, O[i]=0
# 506) dist= 0, Z[i]=0, O[i]=0
# 507) dist= 1, Z[i]=1, O[i]=0
# 508) dist= 85, Z[i]=85, O[i]=0
# 509) dist= 305, Z[i]=305, O[i]=0
# 510) dist= 514, Z[i]=514, O[i]=0
# 511) dist= 650, Z[i]=652, O[i]=2
# 512) dist= 626, Z[i]=651, O[i]=25
# 513) dist= 423, Z[i]=488, O[i]=65
# 514) dist= 109, Z[i]=288, O[i]=179
# 515) dist= 282, Z[i]=129, O[i]=411
# 516) dist= 580, Z[i]=79, O[i]=659
# 517) dist= 797, Z[i]=90, O[i]=887
# 518) dist= 639, Z[i]=136, O[i]=775
# 519) dist= 201, Z[i]=230, O[i]=431
# 520) dist= 217, Z[i]=358, O[i]=141
# 521) dist= 482, Z[i]=520, O[i]=38
# 522) dist= 631, Z[i]=643, O[i]=12
# 523) dist= 656, Z[i]=662, O[i]=6
# 524) dist= 561, Z[i]=566, O[i]=5
# 525) dist= 388, Z[i]=390, O[i]=2
# 526) dist= 221, Z[i]=221, O[i]=0
# 527) dist= 72, Z[i]=74, O[i]=2
# 528) dist= 9, Z[i]=10, O[i]=1
# 529) dist= 1, Z[i]=1, O[i]=0
# 530) dist= 0, Z[i]=0, O[i]=0
# 531) dist= 0, Z[i]=0, O[i]=0
# 532) dist= 0, Z[i]=0, O[i]=0
# 533) dist= 0, Z[i]=0, O[i]=0
# 534) dist= 0, Z[i]=0, O[i]=0
# 535) dist= 1, Z[i]=1, O[i]=0
# 536) dist= 73, Z[i]=73, O[i]=0
# 537) dist= 267, Z[i]=267, O[i]=0
# 538) dist= 470, Z[i]=472, O[i]=2
# 539) dist= 605, Z[i]=621, O[i]=16
# 540) dist= 627, Z[i]=673, O[i]=46
# 541) dist= 456, Z[i]=576, O[i]=120
# 542) dist= 121, Z[i]=401, O[i]=280
# 543) dist= 188, Z[i]=283, O[i]=471
# 544) dist= 440, Z[i]=229, O[i]=669
# 545) dist= 519, Z[i]=262, O[i]=781
# 546) dist= 320, Z[i]=335, O[i]=655
# 547) dist= 55, Z[i]=446, O[i]=391
# 548) dist= 420, Z[i]=569, O[i]=149
# 549) dist= 607, Z[i]=652, O[i]=45
# 550) dist= 664, Z[i]=679, O[i]=15
# 551) dist= 572, Z[i]=579, O[i]=7
# 552) dist= 405, Z[i]=413, O[i]=8
# 553) dist= 248, Z[i]=249, O[i]=1
# 554) dist= 123, Z[i]=123, O[i]=0
# 555) dist= 36, Z[i]=37, O[i]=1
# 556) dist= 2, Z[i]=2, O[i]=0
# 557) dist= 0, Z[i]=0, O[i]=0
# 558) dist= 0, Z[i]=0, O[i]=0
# 559) dist= 0, Z[i]=0, O[i]=0
# 560) dist= 0, Z[i]=0, O[i]=0
# 561) dist= 0, Z[i]=0, O[i]=0
# 562) dist= 0, Z[i]=0, O[i]=0
# 563) dist= 2, Z[i]=2, O[i]=0
# 564) dist= 43, Z[i]=44, O[i]=1
# 565) dist= 201, Z[i]=201, O[i]=0
# 566) dist= 384, Z[i]=397, O[i]=13
# 567) dist= 558, Z[i]=593, O[i]=35
# 568) dist= 618, Z[i]=700, O[i]=82
# 569) dist= 492, Z[i]=681, O[i]=189
# 570) dist= 273, Z[i]=619, O[i]=346
# 571) dist= 21, Z[i]=518, O[i]=497
# 572) dist= 126, Z[i]=485, O[i]=611
# 573) dist= 179, Z[i]=500, O[i]=679
# 574) dist= 37, Z[i]=557, O[i]=594
# 575) dist= 244, Z[i]=624, O[i]=380
# 576) dist= 503, Z[i]=677, O[i]=174
# 577) dist= 603, Z[i]=670, O[i]=67
# 578) dist= 569, Z[i]=590, O[i]=21
# 579) dist= 415, Z[i]=424, O[i]=9
# 580) dist= 259, Z[i]=268, O[i]=9
# 581) dist= 132, Z[i]=135, O[i]=3
# 582) dist= 52, Z[i]=52, O[i]=0
# 583) dist= 8, Z[i]=9, O[i]=1
# 584) dist= 0, Z[i]=0, O[i]=0
# 585) dist= 0, Z[i]=0, O[i]=0
# 586) dist= 0, Z[i]=0, O[i]=0
# 587) dist= 0, Z[i]=0, O[i]=0
# 588) dist= 0, Z[i]=0, O[i]=0
# 589) dist= 0, Z[i]=0, O[i]=0
# 590) dist= 0, Z[i]=0, O[i]=0
# 591) dist= 3, Z[i]=3, O[i]=0
# 592) dist= 22, Z[i]=22, O[i]=0
# 593) dist= 114, Z[i]=118, O[i]=4
# 594) dist= 258, Z[i]=282, O[i]=24
# 595) dist= 400, Z[i]=462, O[i]=62
# 596) dist= 506, Z[i]=637, O[i]=131
# 597) dist= 507, Z[i]=750, O[i]=243
# 598) dist= 389, Z[i]=769, O[i]=380
# 599) dist= 268, Z[i]=749, O[i]=481
# 600) dist= 170, Z[i]=715, O[i]=545
# 601) dist= 101, Z[i]=710, O[i]=609
# 602) dist= 159, Z[i]=709, O[i]=550
# 603) dist= 329, Z[i]=697, O[i]=368
# 604) dist= 458, Z[i]=653, O[i]=195
# 605) dist= 469, Z[i]=545, O[i]=76
# 606) dist= 372, Z[i]=402, O[i]=30
# 607) dist= 233, Z[i]=243, O[i]=10
# 608) dist= 124, Z[i]=132, O[i]=8
# 609) dist= 52, Z[i]=55, O[i]=3
# 610) dist= 15, Z[i]=17, O[i]=2
# 611) dist= 2, Z[i]=3, O[i]=1
# 612) dist= 0, Z[i]=0, O[i]=0
# 613) dist= 0, Z[i]=0, O[i]=0
# 614) dist= 0, Z[i]=0, O[i]=0
# 615) dist= 0, Z[i]=0, O[i]=0
# 616) dist= 0, Z[i]=0, O[i]=0
# 617) dist= 0, Z[i]=0, O[i]=0
# 618) dist= 0, Z[i]=0, O[i]=0
# 619) dist= 0, Z[i]=0, O[i]=0
# 620) dist= 5, Z[i]=5, O[i]=0
# 621) dist= 47, Z[i]=57, O[i]=10
# 622) dist= 124, Z[i]=154, O[i]=30
# 623) dist= 221, Z[i]=296, O[i]=75
# 624) dist= 318, Z[i]=461, O[i]=143
# 625) dist= 358, Z[i]=612, O[i]=254
# 626) dist= 360, Z[i]=722, O[i]=362
# 627) dist= 351, Z[i]=786, O[i]=435
# 628) dist= 301, Z[i]=765, O[i]=464
# 629) dist= 229, Z[i]=737, O[i]=508
# 630) dist= 210, Z[i]=688, O[i]=478
# 631) dist= 244, Z[i]=594, O[i]=350
# 632) dist= 273, Z[i]=472, O[i]=199
# 633) dist= 247, Z[i]=322, O[i]=75
# 634) dist= 179, Z[i]=208, O[i]=29
# 635) dist= 105, Z[i]=114, O[i]=9
# 636) dist= 42, Z[i]=49, O[i]=7
# 637) dist= 9, Z[i]=11, O[i]=2
# 638) dist= 1, Z[i]=4, O[i]=3
# 639) dist= 0, Z[i]=1, O[i]=1
# 640) dist= 0, Z[i]=0, O[i]=0
# 641) dist= 0, Z[i]=0, O[i]=0
# 642) dist= 0, Z[i]=0, O[i]=0
# 643) dist= 0, Z[i]=0, O[i]=0
# 644) dist= 0, Z[i]=0, O[i]=0
# 645) dist= 0, Z[i]=0, O[i]=0
# 646) dist= 0, Z[i]=0, O[i]=0
# 647) dist= 0, Z[i]=0, O[i]=0
# 648) dist= 0, Z[i]=1, O[i]=1
# 649) dist= 2, Z[i]=10, O[i]=12
# 650) dist= 21, Z[i]=53, O[i]=32
# 651) dist= 32, Z[i]=112, O[i]=80
# 652) dist= 103, Z[i]=228, O[i]=125
# 653) dist= 146, Z[i]=350, O[i]=204
# 654) dist= 178, Z[i]=456, O[i]=278
# 655) dist= 232, Z[i]=536, O[i]=304
# 656) dist= 234, Z[i]=569, O[i]=335
# 657) dist= 153, Z[i]=524, O[i]=371
# 658) dist= 60, Z[i]=428, O[i]=368
# 659) dist= 44, Z[i]=323, O[i]=279
# 660) dist= 60, Z[i]=208, O[i]=148
# 661) dist= 74, Z[i]=133, O[i]=59
# 662) dist= 52, Z[i]=69, O[i]=17
# 663) dist= 22, Z[i]=24, O[i]=2
# 664) dist= 4, Z[i]=7, O[i]=3
# 665) dist= 1, Z[i]=2, O[i]=1
# 666) dist= 1, Z[i]=0, O[i]=1
# 667) dist= 0, Z[i]=0, O[i]=0
# 668) dist= 0, Z[i]=0, O[i]=0
# 669) dist= 0, Z[i]=0, O[i]=0
# 670) dist= 0, Z[i]=0, O[i]=0
# 671) dist= 0, Z[i]=0, O[i]=0
# 672) dist= 0, Z[i]=0, O[i]=0
# 673) dist= 0, Z[i]=0, O[i]=0
# 674) dist= 0, Z[i]=0, O[i]=0
# 675) dist= 0, Z[i]=0, O[i]=0
# 676) dist= 0, Z[i]=0, O[i]=0
# 677) dist= 3, Z[i]=1, O[i]=4
# 678) dist= 7, Z[i]=4, O[i]=11
# 679) dist= 3, Z[i]=17, O[i]=20
# 680) dist= 6, Z[i]=32, O[i]=38
# 681) dist= 6, Z[i]=58, O[i]=64
# 682) dist= 26, Z[i]=94, O[i]=68
# 683) dist= 50, Z[i]=118, O[i]=68
# 684) dist= 51, Z[i]=132, O[i]=81
# 685) dist= 19, Z[i]=120, O[i]=101
# 686) dist= 4, Z[i]=94, O[i]=98
# 687) dist= 2, Z[i]=68, O[i]=70
# 688) dist= 6, Z[i]=40, O[i]=34
# 689) dist= 5, Z[i]=19, O[i]=14
# 690) dist= 5, Z[i]=9, O[i]=4
# 691) dist= 3, Z[i]=3, O[i]=0
# 692) dist= 2, Z[i]=2, O[i]=0
# 693) dist= 1, Z[i]=1, O[i]=0
# 694) dist= 1, Z[i]=0, O[i]=1
# 695) dist= 0, Z[i]=0, O[i]=0
# 696) dist= 0, Z[i]=0, O[i]=0
# 697) dist= 0, Z[i]=0, O[i]=0
# 698) dist= 0, Z[i]=0, O[i]=0
# 699) dist= 0, Z[i]=0, O[i]=0
# 700) dist= 0, Z[i]=0, O[i]=0
# 701) dist= 0, Z[i]=0, O[i]=0
# 702) dist= 0, Z[i]=0, O[i]=0
# 703) dist= 0, Z[i]=0, O[i]=0
# 704) dist= 0, Z[i]=0, O[i]=0
# 705) dist= 0, Z[i]=0, O[i]=0
# 706) dist= 0, Z[i]=0, O[i]=0
# 707) dist= 1, Z[i]=1, O[i]=0
# 708) dist= 2, Z[i]=2, O[i]=0
# 709) dist= 3, Z[i]=3, O[i]=0
# 710) dist= 4, Z[i]=4, O[i]=0
# 711) dist= 5, Z[i]=6, O[i]=1
# 712) dist= 1, Z[i]=3, O[i]=2
# 713) dist= 0, Z[i]=3, O[i]=3
# 714) dist= 3, Z[i]=4, O[i]=1
# 715) dist= 2, Z[i]=3, O[i]=1
# 716) dist= 1, Z[i]=1, O[i]=0
# 717) dist= 0, Z[i]=0, O[i]=0
# 718) dist= 0, Z[i]=0, O[i]=0
# 719) dist= 0, Z[i]=0, O[i]=0
# 720) dist= 0, Z[i]=0, O[i]=0
# 721) dist= 0, Z[i]=0, O[i]=0
# 722) dist= 0, Z[i]=0, O[i]=0
# 723) dist= 0, Z[i]=0, O[i]=0
# 724) dist= 0, Z[i]=0, O[i]=0
# 725) dist= 0, Z[i]=0, O[i]=0
# 726) dist= 0, Z[i]=0, O[i]=0
# 727) dist= 0, Z[i]=0, O[i]=0
# 728) dist= 0, Z[i]=0, O[i]=0
# 729) dist= 0, Z[i]=0, O[i]=0
# 730) dist= 0, Z[i]=0, O[i]=0
# 731) dist= 0, Z[i]=0, O[i]=0
# 732) dist= 0, Z[i]=0, O[i]=0
# 733) dist= 0, Z[i]=0, O[i]=0
# 734) dist= 0, Z[i]=0, O[i]=0
# 735) dist= 0, Z[i]=0, O[i]=0
# 736) dist= 0, Z[i]=0, O[i]=0
# 737) dist= 0, Z[i]=0, O[i]=0
# 738) dist= 0, Z[i]=0, O[i]=0
# 739) dist= 0, Z[i]=0, O[i]=0
# 740) dist= 0, Z[i]=0, O[i]=0
# 741) dist= 0, Z[i]=0, O[i]=0
# 742) dist= 0, Z[i]=0, O[i]=0
# 743) dist= 0, Z[i]=0, O[i]=0
# 744) dist= 0, Z[i]=0, O[i]=0
# 745) dist= 0, Z[i]=0, O[i]=0
# 746) dist= 0, Z[i]=0, O[i]=0
# 747) dist= 0, Z[i]=0, O[i]=0
# 748) dist= 0, Z[i]=0, O[i]=0
# 749) dist= 0, Z[i]=0, O[i]=0
# 750) dist= 0, Z[i]=0, O[i]=0
# 751) dist= 0, Z[i]=0, O[i]=0
# 752) dist= 0, Z[i]=0, O[i]=0
# 753) dist= 0, Z[i]=0, O[i]=0
# 754) dist= 0, Z[i]=0, O[i]=0
# 755) dist= 0, Z[i]=0, O[i]=0
# 756) dist= 0, Z[i]=0, O[i]=0
# 757) dist= 0, Z[i]=0, O[i]=0
# 758) dist= 0, Z[i]=0, O[i]=0
# 759) dist= 0, Z[i]=0, O[i]=0
# 760) dist= 0, Z[i]=0, O[i]=0
# 761) dist= 0, Z[i]=0, O[i]=0
# 762) dist= 0, Z[i]=0, O[i]=0
# 763) dist= 0, Z[i]=0, O[i]=0
# 764) dist= 0, Z[i]=0, O[i]=0
# 765) dist= 0, Z[i]=0, O[i]=0
# 766) dist= 0, Z[i]=0, O[i]=0
# 767) dist= 0, Z[i]=0, O[i]=0
# 768) dist= 0, Z[i]=0, O[i]=0
# 769) dist= 0, Z[i]=0, O[i]=0
# 770) dist= 0, Z[i]=0, O[i]=0
# 771) dist= 0, Z[i]=0, O[i]=0
# 772) dist= 0, Z[i]=0, O[i]=0
# 773) dist= 0, Z[i]=0, O[i]=0
# 774) dist= 0, Z[i]=0, O[i]=0
# 775) dist= 0, Z[i]=0, O[i]=0
# 776) dist= 0, Z[i]=0, O[i]=0
# 777) dist= 0, Z[i]=0, O[i]=0
# 778) dist= 0, Z[i]=0, O[i]=0
# 779) dist= 0, Z[i]=0, O[i]=0
# 780) dist= 0, Z[i]=0, O[i]=0
# 781) dist= 0, Z[i]=0, O[i]=0
# 782) dist= 0, Z[i]=0, O[i]=0
# 783) dist= 0, Z[i]=0, O[i]=0
# Highest dist 1113 at pixel 406 located in position 14x14

# %% [markdown]
# 6. (*) Extract a subset of the MNIST dataset composed of only 0 and 1 digits. Create a Rule-based classifier that take as input the rule that you discovered in ex. 5. As previously then, compute the prediction of such a classifier on all the samples in the dataset

# %%
class RuleModel:
    __rules = []

    def __init__(self, default_class):
        """
        Create the rule-based model.
        :param default_class: default class when no rule applies
        """
        self.__default_class = default_class

    def add_rule(self, rule, output_class):
        """
        Add rule to the model.
        :param rule: lambda function with the conditions on the input sample
        :param output_class: output label to be assigned when the rule is satisfied
        """
        self.__rules.append((rule, output_class))

    def predict(self, x):
        """
        Apply rules to a sample. The first rule that applies represents the output label.
        :param x: dictionary representing the input sample 
        """
        for rule, out_class in self.__rules:
            if rule(x):
                return out_class
        return self.__default_class
    
model = RuleModel(0)
model.add_rule(lambda x: x[406] > 128, 1)

correct_predictions = 0
label = 1
for row in only_one:
    prediction = model.predict(row)
    if prediction == label:
        correct_predictions += 1
    else:
        print(f"Error, predicted {prediction}, actual label {label}")
label = 0
for row in only_zero:
    prediction = model.predict(row)
    if prediction == label:
        correct_predictions += 1
    else:
        print(f"Error, predicted {prediction}, actual label {label}")

# Compute accuracy
accuracy = correct_predictions / len(only_one + only_zero)
print(f"Accuracy of the model: {accuracy}")
# Out:
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 0, actual label 1
# Error, predicted 1, actual label 0
# Error, predicted 1, actual label 0
# Error, predicted 1, actual label 0
# Error, predicted 1, actual label 0
# Error, predicted 1, actual label 0
# Error, predicted 1, actual label 0
# Error, predicted 1, actual label 0
# Accuracy of the model: 0.9895981087470449
